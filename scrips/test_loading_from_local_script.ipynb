# %%
# llibraries
import pandas as pd
import numpy as np

# %%
/Users/xiashuchu/repositories/OTC_MARKETS/hhc390ihqgzwa4hy.csv

# %%
# Read the CSV file in chunks
chunk_size = 500
chunks = pd.read_csv("/Users/xiashuchu/repositories/OTC_MARKETS/hhc390ihqgzwa4hy.csv", chunksize=chunk_size)

# Example: Summarize each chunk or perform any operation
for chunk in chunks:
    print(chunk.head())  # Or perform calculations

# Read specific columns
cols_to_use = ['Column1', 'Column2', 'Column3']
data_partial = pd.read_csv(file_path, usecols=cols_to_use)
print(data_partial.head())

# Skip rows and set no header
data_no_header = pd.read_csv(file_path, header=None, skiprows=10)
print(data_no_header.head())

# %%
# Replace 'path_to_your_file.csv' with the path to your CSV file
file_path = '/Users/xiashuchu/repositories/OTC_MARKETS/hhc390ihqgzwa4hy.csv'

# Read the first 5 rows
data = pd.read_csv(file_path, nrows=5)

# Display the data
print(data)
# Out:
#     SECID  CompID Symbol      CUSIP                 Issue        Venue  \
# 0  100010  649124  GPGPF  G4205Y111  GUINESS PEAT GRP PLC  Grey Market
# 1  100010  649124  GPGPF  G4205Y111  GUINESS PEAT GRP PLC  Grey Market
# 2  100010  649124  GPGPF  G4205Y111  GUINESS PEAT GRP PLC  Grey Market
# 3  100010  649124  GPGPF  G4205Y111  GUINESS PEAT GRP PLC  Grey Market
# 4  100010  649124  GPGPF  G4205Y111  GUINESS PEAT GRP PLC  Grey Market
#
#            SecType  Class CaveatEmptor     TierName  ...  TierID  \
# 0  Ordinary Shares    NaN            N  Grey Market  ...      30
# 1  Ordinary Shares    NaN            N  Grey Market  ...      30
# 2  Ordinary Shares    NaN            N  Grey Market  ...      30
# 3  Ordinary Shares    NaN            N  Grey Market  ...      30
# 4  Ordinary Shares    NaN            N  Grey Market  ...      30
#
#    ClosingBestBid  ClosingBestBidDate  BestBidSource  ClosingBestAsk  \
# 0             NaN          2011-09-01            NaN             NaN
# ...

# %%
data.shape
# Out:
# (5, 44)

# %%
# Iterate over each column in the DataFrame
for column in data.columns:
    print(f"Column: {column}")
    print(data[column])
    print("\n")  # This adds a new line for better readability between columns
# Out:
# Column: SECID
# 0    100010
# 1    100010
# 2    100010
# 3    100010
# 4    100010
# Name: SECID, dtype: int64
#
#
# Column: CompID
# 0    649124
# 1    649124
# 2    649124
# 3    649124
# 4    649124
# Name: CompID, dtype: int64
#
#
# Column: Symbol
# 0    GPGPF
# 1    GPGPF
# 2    GPGPF
# 3    GPGPF
# 4    GPGPF
# Name: Symbol, dtype: object
#
#
# Column: CUSIP
# 0    G4205Y111
# 1    G4205Y111
# 2    G4205Y111
# 3    G4205Y111
# 4    G4205Y111
# Name: CUSIP, dtype: object
#
#
# Column: Issue
# 0    GUINESS PEAT GRP PLC
# 1    GUINESS PEAT GRP PLC
# 2    GUINESS PEAT GRP PLC
# 3    GUINESS PEAT GRP PLC
# 4    GUINESS PEAT GRP PLC
# Name: Issue, dtype: object
#
#
# Column: Venue
# 0    Grey Market
# 1    Grey Market
# 2    Grey Market
# 3    Grey Market
# 4    Grey Market
# Name: Venue, dtype: object
#
#
# Column: SecType
# 0    Ordinary Shares
# 1    Ordinary Shares
# 2    Ordinary Shares
# 3    Ordinary Shares
# 4    Ordinary Shares
# Name: SecType, dtype: object
#
#
# ...
